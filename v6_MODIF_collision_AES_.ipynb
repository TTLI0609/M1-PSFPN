# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad
from Crypto.Random import get_random_bytes
import base64
import random
import math
import doctest
import time
import hashlib
import Crypto.Util.number
import sys
import concurrent.futures

# %%
def key_generator_AES(kp):
    """
    Génere une clef de 16 octets avec kp bits significatives
    >>> kp = 10
    >>> len(key_generator_AES(kp)) == 16
    True
    """
    prng = random.SystemRandom()
    n = prng.getrandbits(kp)
    n = n.to_bytes(16, byteorder='little')
    return n
# Out:
# TestResults(failed=0, attempted=2)

# %%
def extract_bits(x, kp):
    """         
    Extrait kp bits de x, où x est de type byte
    >>> kp = 10
    >>> x = key_generator_AES(kp)
    >>> len (extract_bits(x, kp) ) == (kp//8 + 1)
    True
    """
    res = list(x[0:kp//8])
    tmp = kp - ((kp//8)*8)
    if  tmp > 0 :
        res.append(x[kp//8] &  ((2**tmp)-1))   
    return bytes(res)
# Out:
# TestResults(failed=0, attempted=5)

# %%
def simple_enc_AES(msg, key, mode = 'MODE_ECB'):
    """
    Chiffrer AES
    Retourne le message chiffré par l'AES en bytes
    """
    if not (isinstance(msg,bytes)):
        msg = msg.encode()
        
    cipher = AES.new(key, AES.MODE_ECB)
    enc = cipher.encrypt(pad(msg, len(key)))
    return enc

def simple_dec_AES(msg, key, mode = 'MODE_ECB'):
    """
    Dechiffrer AES
    Retourne le message non unpader et en bytes
    
    ATTENTION => le retour n'est pas UNPADER, fo utiliser unpad !!!
    
    >>> msg = 'test'
    >>> key = key_generator_AES(10)
    >>> encrypt = simple_enc_AES(msg, key)
    >>> unpad(simple_dec_AES(encrypt,key),16).decode()
    'test'
    """
    cipher = AES.new(key, AES.MODE_ECB)
    plaintext = cipher.decrypt(msg)
    
    # error de padding si clef incorrevt
    #return unpad(plaintext, len(key))  
    return plaintext
# Out:
# TestResults(failed=0, attempted=9)

# %%
def double_AES(msg, key1, key2,  mode = 'MODE_ECB'):
    """
    Faire le double chiffrement AES
    en passant les 2 clefs key1 et key2 en parametres
    (on a pas defini les autres modes)
    """
    enc = simple_enc_AES(msg, key1)
    enc = simple_enc_AES(enc, key2)
    return enc

# %%
kp = 3*8
key1 = key_generator_AES(kp)
key2 = key_generator_AES(kp)
M1 = "Voici le message 1"
C1 = double_AES(M1,key1,key2)
M2 = "Voici le message 2"
C2 = double_AES(M2,key1,key2)

# %%
def new_step_cte(f, M, kp, x, cte, p):
    
    """
    passer d'un xi au suivant
    >>> x = extract_bits(key_generator_AES(13),13)
    >>> p = Crypto.Util.number.getPrime(10, randfunc=Crypto.Random.get_random_bytes)
    >>> type(new_step_cte(simple_enc_AES, 'test', 10, x, 2, p))
    <class 'bytes'>
    >>> len(new_step_cte(simple_enc_AES, 'test', 10, x, 2, p)) == 16
    True
    """
    
    if len(x) < 16:                     # des fois les 8 premiers bits sont nuls
        x = x.rjust(16,b"\x00")    
    c = f(M, x)
    c = bytearray(c)
    tmp = (kp // 8) + 1
    for i in range (tmp):
        if( c[i]<<cte != 0):
            c[i] = (c[i]<<cte)&255
        else:
            c[i] = ((c[i]<<cte)%p )&255
         

    tmp = extract_bits(c,kp)
    tmp += b"\0" * (16 - (kp//8) - 1)    
    if len(tmp) < 16:                     # des fois les 8 premiers bits sont nuls
        tmp = tmp.ljust(16,b"\x00") 
        
    return tmp
# Out:
# TestResults(failed=0, attempted=13)

# %%
def trail(f, msg, kp, l, x0, cte, p):
    """
    Retourne un triplet (x0, xd, d) 
    f : fonction chiffrement OU dechiffrement
    msg : message clair OU chiffré deux fois  
    kp :nb de bit significatif de la clef
    l : nb de bit à 0 (pour la condition d'arrêt)
    
    >>> msg = "Voici le message"
    >>> x0 = key_generator_AES(kp)
    >>> kp = 10
    >>> p = Crypto.Util.number.getPrime(kp, randfunc=Crypto.Random.get_random_bytes)
    >>> l = 3
    >>> cte = 2
    >>> (x0,xd,d) = trail(simple_enc_AES, msg, kp, l, x0, cte, p)
    >>> tmp = x0
    >>> for _ in range(d):
    ...    tmp = new_step_cte(simple_enc_AES, msg, kp, tmp, cte, p)     
    >>> print(tmp==xd)
    True
    
    >>> mask_l = 2**l - 1 
    >>> xd = extract_bits(xd,kp)
    >>> xd = int.from_bytes(xd, 'big')
    >>> print( xd & mask_l == 0 )
    True
    """
    
    tmp = x0

    d = 0                                # compter le nb de pas
    max_it = (20/ (1/(2**l))) // 3       # diviser par 3 car sinon ca prends tres longtemps
    mask_l = 2**l - 1               
    
    while True:
        
        if len(tmp) < 16:                # des fois les 8 premiers bits sont nuls alors la clef devient trop courte 
            tmp = tmp.rjust(16,b"\x00")  # après la conversion de bits en byte
        if d == max_it:
            #print("Risque de cycle ")
            return None
        
        tmp_binary = extract_bits(tmp,kp) #bytes_to_bin(tmp)[:kp+2]
        tmp_binary = int.from_bytes(tmp_binary, "big")        
        if tmp_binary & mask_l == 0:  # condition d'arret
            xd = tmp
            break
            
        d += 1
        tmp = new_step_cte(f, msg, kp, tmp, cte, p)       
    return (x0, xd, d)
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=27)

# %%
def F(b):
    """
    Choisir une fonction 
    b : 0 OU 1
    
    0 correspond à simple_enc_AES
    1 correspond à simple_dec_AES
    """
    if b == 0:
        return simple_enc_AES
    if b == 1:
        return simple_dec_AES

# %%
def remonter (F, A, B, M, C, kp, b, cte, p):
    """
    Returne ( (x, f1) , (y, f2) ) tq x != y et f1(x) == f2(y)
    F : choix entre chiffrement et déchiffrement 
    A, B : triplet (x0, xd, d)
    M, C : clair et chiffré double
    kp : nb de bits significatif de la clef
    b : 0 ou 1
    """       
    couple = [M,C]
    cpt = 0
    if A[2] >= B[2]: 

        x = A[0]
        for _ in range(A[2]-B[2]):
            x =  new_step_cte(F(b), couple[b], kp, x, cte, p)
        y = B[0]
        if x == y : 
            #print('pb : x==y et fhash(x)==fhash(y)')
            return None

        while True:
            if x == y :
                break
            tmp1 = x            
            tmp2 = y             # anciennes valeurs
            x =  new_step_cte(F(b), couple[b], kp, tmp1, cte, p)
            y = new_step_cte(F(1-b), couple[1-b], kp, tmp2, cte, p)
            
            if cpt>1000: # boucle ??
                #print("boucle ??")
                return None
            cpt+=1
            
        return (   (tmp1, b) , (tmp2, 1-b)    )
        
        
    else:          # A[2] < B[2] mais on fait la meme chose
        y = B[0]
        for _ in range(B[2]-A[2]):
            y =  new_step_cte(F(1-b), couple[1-b], kp, y, cte, p)
        x = A[0]
        if x == y : 
            #print('pb : x==y et fhash(x)==fhash(y)')
            return None

        while True:
            if x == y :
                break

            tmp1 = x            
            tmp2 = y             # anciennes valeurs
            x = new_step_cte(F(b), couple[b], kp, tmp1, cte, p)
            y = new_step_cte(F(1-b), couple[1-b], kp, tmp2, cte, p)
            
            if cpt>1000: # boucle ??
                #print("boucle ?")
                return None
            cpt+=1

        return (   (tmp1, b) , (tmp2, 1-b)    )

# %%
def collision_detection(F, M, C, kp, l, dico, cte, p):
    """
    Detecte une seule collision
    Retourne le couple ( (x, f1) , (y, f2) ) tq x != y et f1(x) == f2(y) 
    F : choix entre chiffrement et déchiffrement 
    M, C : clair et chiffré double
    kp : nb de bits significatif de la clef
    l : nb de bits pour la condition d'arrêt
    dico : contenant les collisions trouvées
    
    >>> kp = 10
    >>> cte = 5
    >>> key1 = key_generator_AES(kp)
    >>> key2 = key_generator_AES(kp)
    >>> M = 'Voici le message'
    >>> C = double_AES(M, key1, key2)
    >>> l = 4
    >>> p = Crypto.Util.number.getPrime(kp, randfunc=Crypto.Random.get_random_bytes)
    >>> dico = {}
    >>> res = collision_detection(F, M, C, kp, l, dico, cte, p)
    >>> if (res[0][1]==0):  
    ...     enc = simple_enc_AES(M,res[0][0])
    ...     dec = simple_dec_AES(C, res[1][0])
    ... elif (res[0][1]==1):
    ...     enc = simple_enc_AES(M,res[1][0])
    ...     dec = simple_dec_AES(C, res[0][0])
    >>> print(enc[:kp//8])
    >>> print(dec[:kp//8])
    >>> print(res)
    >>> print("key 1 = ", key1, "key 2 = ", key2)
    True
    """
    
    couple = [M,C]
    seuil = 10000                  # valeur estimé pour le nb max d'éléments dans le dico
    
    while True: 
        b = random.randint(0,1) 
        x0 = key_generator_AES(kp)           # clef aléatoire initiale
        res = trail(F(b),couple[b], kp, l, x0, cte, p)
        if res == None:
            continue
            
        x0, xd, d = res

        if (xd,1-b) in dico:        # collision trouvée
            A = (x0,xd,d)                                   # b
            B = (dico[(xd,1-b)][0], xd, dico[(xd,1-b)][1])  # 1-b
            tmp = remonter(F, A , B, M, C, kp, b, cte, p )
            if(tmp == None):
                continue
            else: 
                return tmp
        
        # si la taille du dico depasse la limite fixée, choix aléatoire de la victime
        if len(dico) >= seuil:      
            delete = random.choice(list(dico.keys()))
            dico.pop(delete)
            
        dico[(xd,b)] = (x0, d)

# %%
class Statistics:
    n_new_collisions = 0
    n_idem_collisions = 0
    def __init__(self):
        pass

# %%
def golden_collision(F, M1, C1, M2, C2 ,kp, l):
    """
    Trouve la golden collision en vérifiant à chaque fois
    les clefs obtenus avec (M2, C2)
    F : choix entre chiffrement et déchiffrement 
    M1, C1 : clair et chiffré double pour trouver les collisions
    M2, C2 : clair et chiffré double pour la vérificaiton
    kp : nb de bits significatif de la clef
    l : nb de bits pour la condition d'arrêt
    """
    dico = {}
    liste = []
    stat = Statistics()
    i=1
    cte = 2
    ancient = stat.n_new_collisions
    p = Crypto.Util.number.getPrime(kp, randfunc=Crypto.Random.get_random_bytes)
    while True:
        
        if i%500==0:    
            print("Le nombre de new collisions",stat.n_new_collisions)
            print("Le nombre de collisions idem",stat.n_idem_collisions)
            if ancient == stat.n_new_collisions : # changer de version de new_step  quand l'ancienne version ne trouve plus de nouveau collision                  
                cte += 1
                print("\nOn varie NEW_STEP, on utilise la constante "+str(cte))
            else :
                ancient = stat.n_new_collisions
                      
        colli = collision_detection(F, M1, C1, kp, l,dico, cte, p)

        if colli == None:
            print('None')
            continue

        if colli in liste or (colli[1],colli[0]) in liste: # si collision deja trouvé 
            stat.n_idem_collisions += 1
            i+=1    
            continue 
          
        stat.n_new_collisions += 1
        liste.append(colli)
        
        if (len(liste)==((2**kp)*(2**kp))):
            print('GROOS PB !!!!!' )
            return (liste, None)                      # pour debug
        
        
        try: 
            if colli[0][1] == 0:      # 0 correspond a enc
                tmp1 = simple_enc_AES(M2, colli[0][0])
                tmp2 = unpad(simple_dec_AES(C2, colli[1][0]), 16)
            else:
                tmp1 = unpad(simple_dec_AES(C2, colli[0][0]),16)
                tmp2 = simple_enc_AES(M2, colli[1][0])
            if( tmp1 == tmp2):
                
                from IPython.display import clear_output
                clear_output(wait=True)  # clear cell output 
                
                print( "GOLDEN COLLISION ! ")
                print("Voici la collision :",colli)
                print("On a utiliser:",i,"iterations")
                return (liste,colli)              # liste pour debug
        except ValueError:
            pass      
        i+=1

# %%
def golden_collision_parr(F, M1, C1, M2, C2 ,kp, l):
    """
    Trouve la golden collision en vérifiant à chaque fois
    les clefs obtenus avec (M2, C2)
    F : choix entre chiffrement et déchiffrement 
    M1, C1 : clair et chiffré double pour trouver les collisions
    M2, C2 : clair et chiffré double pour la vérificaiton
    kp : nb de bits significatif de la clef
    l : nb de bits pour la condition d'arrêt
    """
    dico = {}
    liste = []
    stat = Statistics()
    i=1
    cte = 2
    ancient = stat.n_new_collisions

    while True:
                     
        #colli = collision_detection(F, M1, C1, kp, l,dico, version_new_step)
        

        pool = concurrent.futures.ProcessPoolExecutor()
        futures = []
        for x in range(500):
            futures.append(pool.submit(collision_detection, F, M1, C1, kp, l,dico, cte))

        #    print(x)
       # print("fin")
        for x in (futures):
           # print("x en cour")
            #sleep(1)
            if i%200==0:  
                print("Le nombre de new collisions",stat.n_new_collisions)
                print("Le nombre de collisions idem",stat.n_idem_collisions)
                if ancient == stat.n_new_collisions : # changer de version de new_step  quand l'ancienne version ne trouve plus de nouveau collision                  
                    cte += 1
                    print()
                    print("On varie NEW_STEP, avec la constante : "+str(cte))
                else :
                    ancient = stat.n_new_collisions
                    
            colli = (x.result())
            if colli == None:
                print('None')
                continue

            if colli in liste or (colli[1],colli[0]) in liste: # si collision deja trouvé 
                stat.n_idem_collisions += 1
                i+=1    
                continue 

            stat.n_new_collisions += 1
            liste.append(colli)

            try: 

                if colli[0][1] == 0:      # 0 correspond a enc
                    tmp1 = simple_enc_AES(M2, colli[0][0])
                    tmp2 = unpad(simple_dec_AES(C2, colli[1][0]), 16)
                else:
                    tmp1 = unpad(simple_dec_AES(C2, colli[0][0]),16)
                    tmp2 = simple_enc_AES(M2, colli[1][0])
                if( tmp1 == tmp2):
                    print("AAAAAAAAAAAAAAAAAAAAAAAAAAAA")
                    from IPython.display import clear_output
                    clear_output(wait=True)  # clear cell output 

                    print( "GOLDEN COLLISION ! ")
                    print("Voici la collision :",colli)
                    print("On a utiliser:",i,"iterations")
                    return (liste,colli)              # liste pour debug
            except ValueError:
                pass  
            i+=1

# %%
kp = 9
l=4

key1 = key_generator_AES(kp)
key2 = key_generator_AES(kp)
M1 = "Voici le message 1"
C1 = double_AES(M1,key1,key2)
M2 = "Voici le message 2"
C2 = double_AES(M2,key1,key2)

print("Voici la clef 1 : ",key1)
print("Voici la clef 1 : ",key2)
# Out:
# Voici la clef 1 :  b'%\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# Voici la clef 1 :  b'K\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
debut = time.time()
res = golden_collision(F, M1, C1,M2,C2 ,kp, l )
fin = time.time()
print("Le temps utilisé :", fin-debut)
# Out:
# Le nombre de new collisions 348
# Le nombre de collisions idem 151
# Le nombre de new collisions 572
# Le nombre de collisions idem 427
# Le nombre de new collisions 713
# Le nombre de collisions idem 786
# Le nombre de new collisions 812
# Le nombre de collisions idem 1187
# Le nombre de new collisions 883
# Le nombre de collisions idem 1616
# Le nombre de new collisions 931
# Le nombre de collisions idem 2068
# Le nombre de new collisions 964
# Le nombre de collisions idem 2535
# Le nombre de new collisions 985
# Le nombre de collisions idem 3014
# Le nombre de new collisions 990
# Le nombre de collisions idem 3509
# Le nombre de new collisions 999
# Le nombre de collisions idem 4000
# Le nombre de new collisions 1008
# Le nombre de collisions idem 4491
# Le nombre de new collisions 1014
# Le nombre de collisions idem 4985
# Le nombre de new collisions 1016
# Le nombre de collisions idem 5483
# Le nombre de new collisions 1016
# Le nombre de collisions idem 5983
#
# On varie NEW_STEP, on utilise la constante 3
# Le nombre de new collisions 1217
# Le nombre de collisions idem 6282
# Le nombre de new collisions 1377
# Le nombre de collisions idem 6622
# Le nombre de new collisions 1510
# Le nombre de collisions idem 6989
# Le nombre de new collisions 1606
# Le nombre de collisions idem 7393
# Le nombre de new collisions 1695
# Le nombre de collisions idem 7804
# Le nombre de new collisions 1758
# Le nombre de collisions idem 8241
# Le nombre de new collisions 1805
# Le nombre de collisions idem 8694
# Le nombre de new collisions 1846
# Le nombre de collisions idem 9153
# Le nombre de new collisions 1888
# Le nombre de collisions idem 9611
# Le nombre de new collisions 1926
# Le nombre de collisions idem 10073
# Le nombre de new collisions 1949
# Le nombre de collisions idem 10550
# Le nombre de new collisions 1966
# Le nombre de collisions idem 11033
# Le nombre de new collisions 1983
# Le nombre de collisions idem 11516
# Le nombre de new collisions 1998
# Le nombre de collisions idem 12001
# Le nombre de new collisions 2013
# Le nombre de collisions idem 12486
# Le nombre de new collisions 2027
# Le nombre de collisions idem 12972
# Le nombre de new collisions 2036
# Le nombre de collisions idem 13463
# Le nombre de new collisions 2040
# Le nombre de collisions idem 13959
# Le nombre de new collisions 2044
# Le nombre de collisions idem 14455
# Le nombre de new collisions 2046
# Le nombre de collisions idem 14953
# Le nombre de new collisions 2051
# Le nombre de collisions idem 15448
# Le nombre de new collisions 2052
# Le nombre de collisions idem 15947
# Le nombre de new collisions 2052
# Le nombre de collisions idem 16447
#
# On varie NEW_STEP, on utilise la constante 4
# Le nombre de new collisions 2273
# Le nombre de collisions idem 16726
# Le nombre de new collisions 2464
# Le nombre de collisions idem 17035
# Le nombre de new collisions 2649
# Le nombre de collisions idem 17350
# Le nombre de new collisions 2793
# Le nombre de collisions idem 17706
# Le nombre de new collisions 2926
# Le nombre de collisions idem 18073
# Le nombre de new collisions 3037
# Le nombre de collisions idem 18462
# Le nombre de new collisions 3142
# Le nombre de collisions idem 18857
# Le nombre de new collisions 3236
# Le nombre de collisions idem 19263
# Le nombre de new collisions 3309
# Le nombre de collisions idem 19690
# Le nombre de new collisions 3409
# Le nombre de collisions idem 20090
# Le nombre de new collisions 3468
# Le nombre de collisions idem 20531
# Le nombre de new collisions 3538
# Le nombre de collisions idem 20961
# Le nombre de new collisions 3587
# Le nombre de collisions idem 21412
# Le nombre de new collisions 3633
# Le nombre de collisions idem 21866
# Le nombre de new collisions 3678
# Le nombre de collisions idem 22321
# Le nombre de new collisions 3717
# Le nombre de collisions idem 22782
# Le nombre de new collisions 3753
# Le nombre de collisions idem 23246
# Le nombre de new collisions 3783
# Le nombre de collisions idem 23716
# Le nombre de new collisions 3802
# Le nombre de collisions idem 24197
# Le nombre de new collisions 3825
# Le nombre de collisions idem 24674
# Le nombre de new collisions 3847
# Le nombre de collisions idem 25152
# Le nombre de new collisions 3864
# Le nombre de collisions idem 25635
# Le nombre de new collisions 3874
# Le nombre de collisions idem 26125
# Le nombre de new collisions 3893
# Le nombre de collisions idem 26606
# Le nombre de new collisions 3904
# Le nombre de collisions idem 27095
# Le nombre de new collisions 3913
# Le nombre de collisions idem 27586
# Le nombre de new collisions 3929
# Le nombre de collisions idem 28070
# Le nombre de new collisions 3939
# Le nombre de collisions idem 28560
# Le nombre de new collisions 3955
# Le nombre de collisions idem 29044
# Le nombre de new collisions 3966
# Le nombre de collisions idem 29533
# Le nombre de new collisions 3971
# Le nombre de collisions idem 30028
# Le nombre de new collisions 3980
# Le nombre de collisions idem 30519
# Le nombre de new collisions 3986
# Le nombre de collisions idem 31013
# Le nombre de new collisions 3993
# Le nombre de collisions idem 31506
# Le nombre de new collisions 4000
# Le nombre de collisions idem 31999
# Le nombre de new collisions 4005
# Le nombre de collisions idem 32494
# Le nombre de new collisions 4014
# Le nombre de collisions idem 32985
# Le nombre de new collisions 4016
# Le nombre de collisions idem 33483
# Le nombre de new collisions 4018
# Le nombre de collisions idem 33981
# Le nombre de new collisions 4019
# Le nombre de collisions idem 34480
# Le nombre de new collisions 4020
# Le nombre de collisions idem 34979
# Le nombre de new collisions 4024
# Le nombre de collisions idem 35475
# Le nombre de new collisions 4025
# Le nombre de collisions idem 35974
# Le nombre de new collisions 4030
# Le nombre de collisions idem 36469
# Le nombre de new collisions 4032
# Le nombre de collisions idem 36967
# Le nombre de new collisions 4035
# Le nombre de collisions idem 37464
# Le nombre de new collisions 4037
# Le nombre de collisions idem 37962
# Le nombre de new collisions 4039
# Le nombre de collisions idem 38460
# Le nombre de new collisions 4039
# Le nombre de collisions idem 38960
#
# On varie NEW_STEP, on utilise la constante 5
# Le nombre de new collisions 4290
# Le nombre de collisions idem 39209
# Le nombre de new collisions 4497
# Le nombre de collisions idem 39502
# Le nombre de new collisions 4702
# Le nombre de collisions idem 39797
# Le nombre de new collisions 4902
# Le nombre de collisions idem 40097
# Le nombre de new collisions 5085
# Le nombre de collisions idem 40414
# Le nombre de new collisions 5271
# Le nombre de collisions idem 40728
# Le nombre de new collisions 5460
# Le nombre de collisions idem 41039
# Le nombre de new collisions 5635
# Le nombre de collisions idem 41364
# Le nombre de new collisions 5769
# Le nombre de collisions idem 41730
# Le nombre de new collisions 5920
# Le nombre de collisions idem 42079
# Le nombre de new collisions 6040
# Le nombre de collisions idem 42459
# Le nombre de new collisions 6163
# Le nombre de collisions idem 42836
# Le nombre de new collisions 6279
# Le nombre de collisions idem 43220
# Le nombre de new collisions 6386
# Le nombre de collisions idem 43613
# Le nombre de new collisions 6478
# Le nombre de collisions idem 44021
# Le nombre de new collisions 6562
# Le nombre de collisions idem 44437
# Le nombre de new collisions 6645
# Le nombre de collisions idem 44854
# Le nombre de new collisions 6737
# Le nombre de collisions idem 45262
# Le nombre de new collisions 6830
# Le nombre de collisions idem 45669
# Le nombre de new collisions 6901
# Le nombre de collisions idem 46098
# Le nombre de new collisions 6975
# Le nombre de collisions idem 46524
# Le nombre de new collisions 7062
# Le nombre de collisions idem 46937
# Le nombre de new collisions 7131
# Le nombre de collisions idem 47368
# Le nombre de new collisions 7197
# Le nombre de collisions idem 47802
# Le nombre de new collisions 7243
# Le nombre de collisions idem 48256
# Le nombre de new collisions 7293
# Le nombre de collisions idem 48706
# Le nombre de new collisions 7342
# Le nombre de collisions idem 49157
# Le nombre de new collisions 7398
# Le nombre de collisions idem 49601
# Le nombre de new collisions 7428
# Le nombre de collisions idem 50071
# Le nombre de new collisions 7459
# Le nombre de collisions idem 50540
# Le nombre de new collisions 7493
# Le nombre de collisions idem 51006
# Le nombre de new collisions 7516
# Le nombre de collisions idem 51483
# Le nombre de new collisions 7543
# Le nombre de collisions idem 51956
# Le nombre de new collisions 7581
# Le nombre de collisions idem 52418
# Le nombre de new collisions 7616
# Le nombre de collisions idem 52883
# Le nombre de new collisions 7644
# Le nombre de collisions idem 53355
# Le nombre de new collisions 7667
# Le nombre de collisions idem 53832
# Le nombre de new collisions 7704
# Le nombre de collisions idem 54295
# Le nombre de new collisions 7741
# Le nombre de collisions idem 54758
# Le nombre de new collisions 7763
# Le nombre de collisions idem 55236
# Le nombre de new collisions 7789
# Le nombre de collisions idem 55710
# Le nombre de new collisions 7811
# Le nombre de collisions idem 56188
# Le nombre de new collisions 7832
# Le nombre de collisions idem 56667
# Le nombre de new collisions 7844
# Le nombre de collisions idem 57155
# Le nombre de new collisions 7863
# Le nombre de collisions idem 57636
# Le nombre de new collisions 7882
# Le nombre de collisions idem 58117
# Le nombre de new collisions 7898
# Le nombre de collisions idem 58601
# Le nombre de new collisions 7912
# Le nombre de collisions idem 59087
# Le nombre de new collisions 7931
# Le nombre de collisions idem 59568
# Le nombre de new collisions 7945
# Le nombre de collisions idem 60054
# Le nombre de new collisions 7958
# Le nombre de collisions idem 60541
# Le nombre de new collisions 7970
# Le nombre de collisions idem 61029
# Le nombre de new collisions 7982
# Le nombre de collisions idem 61517
# Le nombre de new collisions 7984
# Le nombre de collisions idem 62015
# Le nombre de new collisions 7994
# Le nombre de collisions idem 62505
# Le nombre de new collisions 7998
# Le nombre de collisions idem 63001
# Le nombre de new collisions 8008
# Le nombre de collisions idem 63491
# Le nombre de new collisions 8019
# Le nombre de collisions idem 63980
# Le nombre de new collisions 8024
# Le nombre de collisions idem 64475
# Le nombre de new collisions 8031
# Le nombre de collisions idem 64968
# Le nombre de new collisions 8036
# Le nombre de collisions idem 65463
# Le nombre de new collisions 8043
# Le nombre de collisions idem 65956
# Le nombre de new collisions 8053
# Le nombre de collisions idem 66446
# Le nombre de new collisions 8061
# Le nombre de collisions idem 66938
# Le nombre de new collisions 8067
# Le nombre de collisions idem 67432
# Le nombre de new collisions 8075
# Le nombre de collisions idem 67924
# Le nombre de new collisions 8084
# Le nombre de collisions idem 68415
# Le nombre de new collisions 8093
# Le nombre de collisions idem 68906
# Le nombre de new collisions 8095
# Le nombre de collisions idem 69404
# Le nombre de new collisions 8096
# Le nombre de collisions idem 69903
# Le nombre de new collisions 8101
# Le nombre de collisions idem 70398
# Le nombre de new collisions 8105
# Le nombre de collisions idem 70894
# Le nombre de new collisions 8109
# Le nombre de collisions idem 71390
# Le nombre de new collisions 8111
# Le nombre de collisions idem 71888
# Le nombre de new collisions 8114
# Le nombre de collisions idem 72385
# Le nombre de new collisions 8115
# Le nombre de collisions idem 72884
# Le nombre de new collisions 8117
# Le nombre de collisions idem 73382
# Le nombre de new collisions 8118
# Le nombre de collisions idem 73881
# Le nombre de new collisions 8120
# Le nombre de collisions idem 74379
# Le nombre de new collisions 8122
# Le nombre de collisions idem 74877
# Le nombre de new collisions 8123
# Le nombre de collisions idem 75376
# Le nombre de new collisions 8125
# Le nombre de collisions idem 75874
# Le nombre de new collisions 8126
# Le nombre de collisions idem 76373
# Le nombre de new collisions 8129
# Le nombre de collisions idem 76870
# Le nombre de new collisions 8131
# Le nombre de collisions idem 77368
# Le nombre de new collisions 8132
# Le nombre de collisions idem 77867
# Le nombre de new collisions 8134
# Le nombre de collisions idem 78365
# Le nombre de new collisions 8136
# Le nombre de collisions idem 78863
# Le nombre de new collisions 8136
# Le nombre de collisions idem 79363
#
# On varie NEW_STEP, on utilise la constante 6
# Le nombre de new collisions 8380
# Le nombre de collisions idem 79619
# Le nombre de new collisions 8611
# Le nombre de collisions idem 79888
# Le nombre de new collisions 8854
# Le nombre de collisions idem 80145
# Le nombre de new collisions 9073
# Le nombre de collisions idem 80426
# Le nombre de new collisions 9310
# Le nombre de collisions idem 80689
# Le nombre de new collisions 9517
# Le nombre de collisions idem 80982
# Le nombre de new collisions 9707
# Le nombre de collisions idem 81292
# Le nombre de new collisions 9894
# Le nombre de collisions idem 81605
# Le nombre de new collisions 10074
# Le nombre de collisions idem 81925
# Le nombre de new collisions 10259
# Le nombre de collisions idem 82240
# Le nombre de new collisions 10438
# Le nombre de collisions idem 82561
# Le nombre de new collisions 10626
# Le nombre de collisions idem 82873
# Le nombre de new collisions 10777
# Le nombre de collisions idem 83222
# Le nombre de new collisions 10923
# Le nombre de collisions idem 83576
# Le nombre de new collisions 11091
# Le nombre de collisions idem 83908
# Le nombre de new collisions 11228
# Le nombre de collisions idem 84271
# Le nombre de new collisions 11366
# Le nombre de collisions idem 84633
# Le nombre de new collisions 11530
# Le nombre de collisions idem 84969
# Le nombre de new collisions 11661
# Le nombre de collisions idem 85338
# Le nombre de new collisions 11813
# Le nombre de collisions idem 85686
# Le nombre de new collisions 11932
# Le nombre de collisions idem 86067
# Le nombre de new collisions 12062
# Le nombre de collisions idem 86437
# Le nombre de new collisions 12165
# Le nombre de collisions idem 86834
# Le nombre de new collisions 12300
# Le nombre de collisions idem 87199
# Le nombre de new collisions 12428
# Le nombre de collisions idem 87571
# Le nombre de new collisions 12538
# Le nombre de collisions idem 87961
# Le nombre de new collisions 12638
# Le nombre de collisions idem 88361
# Le nombre de new collisions 12739
# Le nombre de collisions idem 88760
# Le nombre de new collisions 12831
# Le nombre de collisions idem 89168
# Le nombre de new collisions 12949
# Le nombre de collisions idem 89550
# Le nombre de new collisions 13041
# Le nombre de collisions idem 89958
# Le nombre de new collisions 13135
# Le nombre de collisions idem 90364
# Le nombre de new collisions 13220
# Le nombre de collisions idem 90779
# Le nombre de new collisions 13294
# Le nombre de collisions idem 91205
# Le nombre de new collisions 13390
# Le nombre de collisions idem 91609
# Le nombre de new collisions 13463
# Le nombre de collisions idem 92036
# Le nombre de new collisions 13555
# Le nombre de collisions idem 92444
# Le nombre de new collisions 13623
# Le nombre de collisions idem 92876
# Le nombre de new collisions 13709
# Le nombre de collisions idem 93290
# Le nombre de new collisions 13796
# Le nombre de collisions idem 93703
# Le nombre de new collisions 13877
# Le nombre de collisions idem 94122
# Le nombre de new collisions 13942
# Le nombre de collisions idem 94557
# Le nombre de new collisions 14005
# Le nombre de collisions idem 94994
# Le nombre de new collisions 14060
# Le nombre de collisions idem 95439
# Le nombre de new collisions 14122
# Le nombre de collisions idem 95877
# Le nombre de new collisions 14185
# Le nombre de collisions idem 96314
# Le nombre de new collisions 14243
# Le nombre de collisions idem 96756
# Le nombre de new collisions 14297
# Le nombre de collisions idem 97202
# Le nombre de new collisions 14341
# Le nombre de collisions idem 97658
# Le nombre de new collisions 14399
# Le nombre de collisions idem 98100
# Le nombre de new collisions 14458
# Le nombre de collisions idem 98541
# Le nombre de new collisions 14493
# Le nombre de collisions idem 99006
# Le nombre de new collisions 14543
# Le nombre de collisions idem 99456
# Le nombre de new collisions 14601
# Le nombre de collisions idem 99898
# Le nombre de new collisions 14650
# Le nombre de collisions idem 100349
# Le nombre de new collisions 14698
# Le nombre de collisions idem 100801
# Le nombre de new collisions 14734
# Le nombre de collisions idem 101265
# Le nombre de new collisions 14769
# Le nombre de collisions idem 101730
# Le nombre de new collisions 14811
# Le nombre de collisions idem 102188
# Le nombre de new collisions 14856
# Le nombre de collisions idem 102643
# Le nombre de new collisions 14891
# Le nombre de collisions idem 103108
# Le nombre de new collisions 14927
# Le nombre de collisions idem 103572
# Le nombre de new collisions 14959
# Le nombre de collisions idem 104040
# Le nombre de new collisions 14992
# Le nombre de collisions idem 104507
# Le nombre de new collisions 15032
# Le nombre de collisions idem 104967
# Le nombre de new collisions 15069
# Le nombre de collisions idem 105430
# Le nombre de new collisions 15107
# Le nombre de collisions idem 105892
# Le nombre de new collisions 15137
# Le nombre de collisions idem 106362
# Le nombre de new collisions 15166
# Le nombre de collisions idem 106833
# Le nombre de new collisions 15200
# Le nombre de collisions idem 107299
# Le nombre de new collisions 15231
# Le nombre de collisions idem 107768
# Le nombre de new collisions 15267
# Le nombre de collisions idem 108232
# Le nombre de new collisions 15300
# Le nombre de collisions idem 108699
# Le nombre de new collisions 15327
# Le nombre de collisions idem 109172
# Le nombre de new collisions 15356
# Le nombre de collisions idem 109643
# Le nombre de new collisions 15386
# Le nombre de collisions idem 110113
# Le nombre de new collisions 15410
# Le nombre de collisions idem 110589
# Le nombre de new collisions 15441
# Le nombre de collisions idem 111058
# Le nombre de new collisions 15460
# Le nombre de collisions idem 111539
# Le nombre de new collisions 15487
# Le nombre de collisions idem 112012
# Le nombre de new collisions 15507
# Le nombre de collisions idem 112492
# Le nombre de new collisions 15524
# Le nombre de collisions idem 112975
# Le nombre de new collisions 15545
# Le nombre de collisions idem 113454
# Le nombre de new collisions 15570
# Le nombre de collisions idem 113929
# Le nombre de new collisions 15582
# Le nombre de collisions idem 114417
# Le nombre de new collisions 15603
# Le nombre de collisions idem 114896
# Le nombre de new collisions 15617
# Le nombre de collisions idem 115382
# Le nombre de new collisions 15640
# Le nombre de collisions idem 115859
# Le nombre de new collisions 15656
# Le nombre de collisions idem 116343
# Le nombre de new collisions 15664
# Le nombre de collisions idem 116835
# Le nombre de new collisions 15680
# Le nombre de collisions idem 117319
# Le nombre de new collisions 15698
# Le nombre de collisions idem 117801
# Le nombre de new collisions 15724
# Le nombre de collisions idem 118275
# Le nombre de new collisions 15736
# Le nombre de collisions idem 118763
# Le nombre de new collisions 15748
# Le nombre de collisions idem 119251
# Le nombre de new collisions 15757
# Le nombre de collisions idem 119742
# Le nombre de new collisions 15771
# Le nombre de collisions idem 120228
# Le nombre de new collisions 15782
# Le nombre de collisions idem 120717
# Le nombre de new collisions 15794
# Le nombre de collisions idem 121205
# Le nombre de new collisions 15808
# Le nombre de collisions idem 121691
# Le nombre de new collisions 15821
# Le nombre de collisions idem 122178
# Le nombre de new collisions 15833
# Le nombre de collisions idem 122666
# Le nombre de new collisions 15840
# Le nombre de collisions idem 123159
# Le nombre de new collisions 15849
# Le nombre de collisions idem 123650
# Le nombre de new collisions 15862
# Le nombre de collisions idem 124137
# Le nombre de new collisions 15871
# Le nombre de collisions idem 124628
# Le nombre de new collisions 15884
# Le nombre de collisions idem 125115
# Le nombre de new collisions 15895
# Le nombre de collisions idem 125604
# Le nombre de new collisions 15907
# Le nombre de collisions idem 126092
# Le nombre de new collisions 15923
# Le nombre de collisions idem 126576
# Le nombre de new collisions 15930
# Le nombre de collisions idem 127069
# Le nombre de new collisions 15936
# Le nombre de collisions idem 127563
# Le nombre de new collisions 15944
# Le nombre de collisions idem 128055
# Le nombre de new collisions 15948
# Le nombre de collisions idem 128551
# Le nombre de new collisions 15954
# Le nombre de collisions idem 129045
# Le nombre de new collisions 15960
# Le nombre de collisions idem 129539
# Le nombre de new collisions 15965
# Le nombre de collisions idem 130034
# Le nombre de new collisions 15973
# Le nombre de collisions idem 130526
# Le nombre de new collisions 15981
# Le nombre de collisions idem 131018
# Le nombre de new collisions 15992
# Le nombre de collisions idem 131507
# Le nombre de new collisions 15999
# Le nombre de collisions idem 132000
# Le nombre de new collisions 16007
# Le nombre de collisions idem 132492
# Le nombre de new collisions 16012
# Le nombre de collisions idem 132987
# Le nombre de new collisions 16018
# Le nombre de collisions idem 133481
# Le nombre de new collisions 16026
# Le nombre de collisions idem 133973
# Le nombre de new collisions 16028
# Le nombre de collisions idem 134471
# Le nombre de new collisions 16032
# Le nombre de collisions idem 134967
# Le nombre de new collisions 16040
# Le nombre de collisions idem 135459
# Le nombre de new collisions 16042
# Le nombre de collisions idem 135957
# Le nombre de new collisions 16045
# Le nombre de collisions idem 136454
# Le nombre de new collisions 16052
# Le nombre de collisions idem 136947
# Le nombre de new collisions 16056
# Le nombre de collisions idem 137443
# Le nombre de new collisions 16066
# Le nombre de collisions idem 137933
# Le nombre de new collisions 16073
# Le nombre de collisions idem 138426
# Le nombre de new collisions 16079
# Le nombre de collisions idem 138920
# Le nombre de new collisions 16084
# Le nombre de collisions idem 139415
# Le nombre de new collisions 16087
# Le nombre de collisions idem 139912
# Le nombre de new collisions 16090
# Le nombre de collisions idem 140409
# Le nombre de new collisions 16094
# Le nombre de collisions idem 140905
# Le nombre de new collisions 16098
# Le nombre de collisions idem 141401
# Le nombre de new collisions 16101
# Le nombre de collisions idem 141898
# Le nombre de new collisions 16106
# Le nombre de collisions idem 142393
# Le nombre de new collisions 16109
# Le nombre de collisions idem 142890
# Le nombre de new collisions 16117
# Le nombre de collisions idem 143382
# Le nombre de new collisions 16119
# Le nombre de collisions idem 143880
# Le nombre de new collisions 16121
# Le nombre de collisions idem 144378
# Le nombre de new collisions 16122
# Le nombre de collisions idem 144877
# Le nombre de new collisions 16127
# Le nombre de collisions idem 145372
# Le nombre de new collisions 16130
# Le nombre de collisions idem 145869
# Le nombre de new collisions 16134
# Le nombre de collisions idem 146365
# Le nombre de new collisions 16136
# Le nombre de collisions idem 146863
# Le nombre de new collisions 16137
# Le nombre de collisions idem 147362
# Le nombre de new collisions 16138
# Le nombre de collisions idem 147861
# Le nombre de new collisions 16141
# Le nombre de collisions idem 148358
# Le nombre de new collisions 16145
# Le nombre de collisions idem 148854
# Le nombre de new collisions 16148
# Le nombre de collisions idem 149351
# Le nombre de new collisions 16155
# Le nombre de collisions idem 149844
# Le nombre de new collisions 16157
# Le nombre de collisions idem 150342
# Le nombre de new collisions 16158
# Le nombre de collisions idem 150841
# Le nombre de new collisions 16162
# Le nombre de collisions idem 151337
# Le nombre de new collisions 16163
# Le nombre de collisions idem 151836
# Le nombre de new collisions 16166
# Le nombre de collisions idem 152333
# Le nombre de new collisions 16172
# Le nombre de collisions idem 152827
# Le nombre de new collisions 16172
# Le nombre de collisions idem 153327
#
# On varie NEW_STEP, on utilise la constante 7
# Le nombre de new collisions 16419
# Le nombre de collisions idem 153580
# Le nombre de new collisions 16677
# Le nombre de collisions idem 153822
# Le nombre de new collisions 16929
# Le nombre de collisions idem 154070
# Le nombre de new collisions 17171
# Le nombre de collisions idem 154328
# Le nombre de new collisions 17398
# Le nombre de collisions idem 154601
# Le nombre de new collisions 17629
# Le nombre de collisions idem 154870
# Le nombre de new collisions 17863
# Le nombre de collisions idem 155136
# Le nombre de new collisions 18093
# Le nombre de collisions idem 155406
# Le nombre de new collisions 18326
# Le nombre de collisions idem 155673
# Le nombre de new collisions 18542
# Le nombre de collisions idem 155957
# Le nombre de new collisions 18754
# Le nombre de collisions idem 156245
# Le nombre de new collisions 18970
# Le nombre de collisions idem 156529
# Le nombre de new collisions 19184
# Le nombre de collisions idem 156815
# Le nombre de new collisions 19368
# Le nombre de collisions idem 157131
# Le nombre de new collisions 19557
# Le nombre de collisions idem 157442
# Le nombre de new collisions 19770
# Le nombre de collisions idem 157729
# Le nombre de new collisions 19943
# Le nombre de collisions idem 158056
# Le nombre de new collisions 20143
# Le nombre de collisions idem 158356
# Le nombre de new collisions 20332
# Le nombre de collisions idem 158667
# Le nombre de new collisions 20523
# Le nombre de collisions idem 158976
# Le nombre de new collisions 20716
# Le nombre de collisions idem 159283
# Le nombre de new collisions 20896
# Le nombre de collisions idem 159603
# Le nombre de new collisions 21090
# Le nombre de collisions idem 159909
# Le nombre de new collisions 21274
# Le nombre de collisions idem 160225
# Le nombre de new collisions 21449
# Le nombre de collisions idem 160550
# Le nombre de new collisions 21625
# Le nombre de collisions idem 160874
# Le nombre de new collisions 21797
# Le nombre de collisions idem 161202
# Le nombre de new collisions 21957
# Le nombre de collisions idem 161542
# Le nombre de new collisions 22113
# Le nombre de collisions idem 161886
# Le nombre de new collisions 22287
# Le nombre de collisions idem 162212
# Le nombre de new collisions 22439
# Le nombre de collisions idem 162560
# Le nombre de new collisions 22596
# Le nombre de collisions idem 162903
# Le nombre de new collisions 22749
# Le nombre de collisions idem 163250
# Le nombre de new collisions 22890
# Le nombre de collisions idem 163609
# Le nombre de new collisions 23032
# Le nombre de collisions idem 163967
# Le nombre de new collisions 23184
# Le nombre de collisions idem 164315
# Le nombre de new collisions 23313
# Le nombre de collisions idem 164686
# Le nombre de new collisions 23438
# Le nombre de collisions idem 165061
# Le nombre de new collisions 23563
# Le nombre de collisions idem 165436
# Le nombre de new collisions 23693
# Le nombre de collisions idem 165806
# Le nombre de new collisions 23825
# Le nombre de collisions idem 166174
# Le nombre de new collisions 23955
# Le nombre de collisions idem 166544
# Le nombre de new collisions 24079
# Le nombre de collisions idem 166920
# Le nombre de new collisions 24201
# Le nombre de collisions idem 167298
# Le nombre de new collisions 24324
# Le nombre de collisions idem 167675
# Le nombre de new collisions 24462
# Le nombre de collisions idem 168037
# Le nombre de new collisions 24580
# Le nombre de collisions idem 168419
# Le nombre de new collisions 24704
# Le nombre de collisions idem 168795
# Le nombre de new collisions 24813
# Le nombre de collisions idem 169186
# Le nombre de new collisions 24934
# Le nombre de collisions idem 169565
# Le nombre de new collisions 25061
# Le nombre de collisions idem 169938
# Le nombre de new collisions 25181
# Le nombre de collisions idem 170318
# Le nombre de new collisions 25276
# Le nombre de collisions idem 170723
# Le nombre de new collisions 25391
# Le nombre de collisions idem 171108
# Le nombre de new collisions 25511
# Le nombre de collisions idem 171488
# Le nombre de new collisions 25628
# Le nombre de collisions idem 171871
# Le nombre de new collisions 25757
# Le nombre de collisions idem 172242
# Le nombre de new collisions 25863
# Le nombre de collisions idem 172636
# Le nombre de new collisions 25948
# Le nombre de collisions idem 173051
# Le nombre de new collisions 26041
# Le nombre de collisions idem 173458
# Le nombre de new collisions 26145
# Le nombre de collisions idem 173854
# Le nombre de new collisions 26243
# Le nombre de collisions idem 174256
# Le nombre de new collisions 26317
# Le nombre de collisions idem 174682
# Le nombre de new collisions 26408
# Le nombre de collisions idem 175091
# Le nombre de new collisions 26505
# Le nombre de collisions idem 175494
# Le nombre de new collisions 26617
# Le nombre de collisions idem 175882
# Le nombre de new collisions 26724
# Le nombre de collisions idem 176275
# Le nombre de new collisions 26819
# Le nombre de collisions idem 176680
# Le nombre de new collisions 26905
# Le nombre de collisions idem 177094
# Le nombre de new collisions 26994
# Le nombre de collisions idem 177505
# Le nombre de new collisions 27090
# Le nombre de collisions idem 177909
# Le nombre de new collisions 27177
# Le nombre de collisions idem 178322
# Le nombre de new collisions 27281
# Le nombre de collisions idem 178718
# Le nombre de new collisions 27367
# Le nombre de collisions idem 179132
# Le nombre de new collisions 27434
# Le nombre de collisions idem 179565
# Le nombre de new collisions 27518
# Le nombre de collisions idem 179981
# Le nombre de new collisions 27590
# Le nombre de collisions idem 180409
# Le nombre de new collisions 27677
# Le nombre de collisions idem 180822
# Le nombre de new collisions 27747
# Le nombre de collisions idem 181252
# Le nombre de new collisions 27807
# Le nombre de collisions idem 181692
# Le nombre de new collisions 27889
# Le nombre de collisions idem 182110
# Le nombre de new collisions 27959
# Le nombre de collisions idem 182540
# Le nombre de new collisions 28032
# Le nombre de collisions idem 182967
# Le nombre de new collisions 28094
# Le nombre de collisions idem 183405
# Le nombre de new collisions 28166
# Le nombre de collisions idem 183833
# Le nombre de new collisions 28223
# Le nombre de collisions idem 184276
# Le nombre de new collisions 28286
# Le nombre de collisions idem 184713
# Le nombre de new collisions 28347
# Le nombre de collisions idem 185152
# Le nombre de new collisions 28424
# Le nombre de collisions idem 185575
# Le nombre de new collisions 28485
# Le nombre de collisions idem 186014
# Le nombre de new collisions 28546
# Le nombre de collisions idem 186453
# Le nombre de new collisions 28611
# Le nombre de collisions idem 186888
# Le nombre de new collisions 28655
# Le nombre de collisions idem 187344
# Le nombre de new collisions 28716
# Le nombre de collisions idem 187783
# Le nombre de new collisions 28771
# Le nombre de collisions idem 188228
# Le nombre de new collisions 28838
# Le nombre de collisions idem 188661
# Le nombre de new collisions 28896
# Le nombre de collisions idem 189103
# Le nombre de new collisions 28942
# Le nombre de collisions idem 189557
# Le nombre de new collisions 28990
# Le nombre de collisions idem 190009
# Le nombre de new collisions 29048
# Le nombre de collisions idem 190451
# Le nombre de new collisions 29080
# Le nombre de collisions idem 190919
# Le nombre de new collisions 29123
# Le nombre de collisions idem 191376
# Le nombre de new collisions 29166
# Le nombre de collisions idem 191833
# Le nombre de new collisions 29208
# Le nombre de collisions idem 192291
# Le nombre de new collisions 29255
# Le nombre de collisions idem 192744
# Le nombre de new collisions 29304
# Le nombre de collisions idem 193195
# Le nombre de new collisions 29353
# Le nombre de collisions idem 193646
# Le nombre de new collisions 29411
# Le nombre de collisions idem 194088
# Le nombre de new collisions 29466
# Le nombre de collisions idem 194533
# Le nombre de new collisions 29510
# Le nombre de collisions idem 194989
# Le nombre de new collisions 29563
# Le nombre de collisions idem 195436
# Le nombre de new collisions 29591
# Le nombre de collisions idem 195908
# Le nombre de new collisions 29640
# Le nombre de collisions idem 196359
# Le nombre de new collisions 29670
# Le nombre de collisions idem 196829
# Le nombre de new collisions 29713
# Le nombre de collisions idem 197286
# Le nombre de new collisions 29753
# Le nombre de collisions idem 197746
# Le nombre de new collisions 29800
# Le nombre de collisions idem 198199
# Le nombre de new collisions 29854
# Le nombre de collisions idem 198645
# Le nombre de new collisions 29904
# Le nombre de collisions idem 199095
# Le nombre de new collisions 29947
# Le nombre de collisions idem 199552
# Le nombre de new collisions 29987
# Le nombre de collisions idem 200012
# Le nombre de new collisions 30026
# Le nombre de collisions idem 200473
# Le nombre de new collisions 30071
# Le nombre de collisions idem 200928
# Le nombre de new collisions 30108
# Le nombre de collisions idem 201391
# Le nombre de new collisions 30133
# Le nombre de collisions idem 201866
# Le nombre de new collisions 30172
# Le nombre de collisions idem 202327
# Le nombre de new collisions 30208
# Le nombre de collisions idem 202791
# Le nombre de new collisions 30247
# Le nombre de collisions idem 203252
# Le nombre de new collisions 30278
# Le nombre de collisions idem 203721
# Le nombre de new collisions 30321
# Le nombre de collisions idem 204178
# Le nombre de new collisions 30342
# Le nombre de collisions idem 204657
# Le nombre de new collisions 30376
# Le nombre de collisions idem 205123
# Le nombre de new collisions 30425
# Le nombre de collisions idem 205574
# Le nombre de new collisions 30469
# Le nombre de collisions idem 206030
# Le nombre de new collisions 30512
# Le nombre de collisions idem 206487
# Le nombre de new collisions 30555
# Le nombre de collisions idem 206944
# Le nombre de new collisions 30593
# Le nombre de collisions idem 207406
# Le nombre de new collisions 30621
# Le nombre de collisions idem 207878
# Le nombre de new collisions 30647
# Le nombre de collisions idem 208352
# Le nombre de new collisions 30675
# Le nombre de collisions idem 208824
# Le nombre de new collisions 30705
# Le nombre de collisions idem 209294
# Le nombre de new collisions 30732
# Le nombre de collisions idem 209767
# Le nombre de new collisions 30755
# Le nombre de collisions idem 210244
# Le nombre de new collisions 30788
# Le nombre de collisions idem 210711
# Le nombre de new collisions 30821
# Le nombre de collisions idem 211178
# Le nombre de new collisions 30849
# Le nombre de collisions idem 211650
# Le nombre de new collisions 30872
# Le nombre de collisions idem 212127
# Le nombre de new collisions 30901
# Le nombre de collisions idem 212598
# Le nombre de new collisions 30931
# Le nombre de collisions idem 213068
# Le nombre de new collisions 30958
# Le nombre de collisions idem 213541
# Le nombre de new collisions 30990
# Le nombre de collisions idem 214009
# Le nombre de new collisions 31009
# Le nombre de collisions idem 214490
# Le nombre de new collisions 31038
# Le nombre de collisions idem 214961
# Le nombre de new collisions 31057
# Le nombre de collisions idem 215442
# Le nombre de new collisions 31076
# Le nombre de collisions idem 215923
# Le nombre de new collisions 31094
# Le nombre de collisions idem 216405
# Le nombre de new collisions 31123
# Le nombre de collisions idem 216876
# Le nombre de new collisions 31144
# Le nombre de collisions idem 217355
# Le nombre de new collisions 31162
# Le nombre de collisions idem 217837
# Le nombre de new collisions 31187
# Le nombre de collisions idem 218312
# Le nombre de new collisions 31204
# Le nombre de collisions idem 218795
# Le nombre de new collisions 31233
# Le nombre de collisions idem 219266
# Le nombre de new collisions 31251
# Le nombre de collisions idem 219748
# Le nombre de new collisions 31265
# Le nombre de collisions idem 220234
# Le nombre de new collisions 31285
# Le nombre de collisions idem 220714
# Le nombre de new collisions 31315
# Le nombre de collisions idem 221184
# Le nombre de new collisions 31336
# Le nombre de collisions idem 221663
# Le nombre de new collisions 31356
# Le nombre de collisions idem 222143
# Le nombre de new collisions 31377
# Le nombre de collisions idem 222622
# Le nombre de new collisions 31399
# Le nombre de collisions idem 223100
# Le nombre de new collisions 31416
# Le nombre de collisions idem 223583
# Le nombre de new collisions 31433
# Le nombre de collisions idem 224066
# Le nombre de new collisions 31449
# Le nombre de collisions idem 224550
# Le nombre de new collisions 31468
# Le nombre de collisions idem 225031
# Le nombre de new collisions 31492
# Le nombre de collisions idem 225507
# Le nombre de new collisions 31511
# Le nombre de collisions idem 225988
# Le nombre de new collisions 31526
# Le nombre de collisions idem 226473
# Le nombre de new collisions 31538
# Le nombre de collisions idem 226961
# Le nombre de new collisions 31553
# Le nombre de collisions idem 227446
# Le nombre de new collisions 31571
# Le nombre de collisions idem 227928
# Le nombre de new collisions 31587
# Le nombre de collisions idem 228412
# Le nombre de new collisions 31612
# Le nombre de collisions idem 228887
# Le nombre de new collisions 31628
# Le nombre de collisions idem 229371
# Le nombre de new collisions 31642
# Le nombre de collisions idem 229857
# Le nombre de new collisions 31654
# Le nombre de collisions idem 230345
# Le nombre de new collisions 31667
# Le nombre de collisions idem 230832
# Le nombre de new collisions 31674
# Le nombre de collisions idem 231325
# Le nombre de new collisions 31688
# Le nombre de collisions idem 231811
# Le nombre de new collisions 31703
# Le nombre de collisions idem 232296
# Le nombre de new collisions 31714
# Le nombre de collisions idem 232785
# Le nombre de new collisions 31730
# Le nombre de collisions idem 233269
# Le nombre de new collisions 31748
# Le nombre de collisions idem 233751
# Le nombre de new collisions 31764
# Le nombre de collisions idem 234235
# Le nombre de new collisions 31777
# Le nombre de collisions idem 234722
# Le nombre de new collisions 31792
# Le nombre de collisions idem 235207
# Le nombre de new collisions 31803
# Le nombre de collisions idem 235696
# Le nombre de new collisions 31809
# Le nombre de collisions idem 236190
# Le nombre de new collisions 31821
# Le nombre de collisions idem 236678
# Le nombre de new collisions 31833
# Le nombre de collisions idem 237166
# Le nombre de new collisions 31849
# Le nombre de collisions idem 237650
# Le nombre de new collisions 31863
# Le nombre de collisions idem 238136
# Le nombre de new collisions 31871
# Le nombre de collisions idem 238628
# Le nombre de new collisions 31881
# Le nombre de collisions idem 239118
# Le nombre de new collisions 31891
# Le nombre de collisions idem 239608
# Le nombre de new collisions 31901
# Le nombre de collisions idem 240098
# Le nombre de new collisions 31916
# Le nombre de collisions idem 240583
# Le nombre de new collisions 31930
# Le nombre de collisions idem 241069
# Le nombre de new collisions 31938
# Le nombre de collisions idem 241561
# Le nombre de new collisions 31943
# Le nombre de collisions idem 242056
# Le nombre de new collisions 31953
# Le nombre de collisions idem 242546
# Le nombre de new collisions 31961
# Le nombre de collisions idem 243038
# Le nombre de new collisions 31972
# Le nombre de collisions idem 243527
# Le nombre de new collisions 31977
# Le nombre de collisions idem 244022
# Le nombre de new collisions 31988
# Le nombre de collisions idem 244511
# Le nombre de new collisions 31999
# Le nombre de collisions idem 245000
# Le nombre de new collisions 32012
# Le nombre de collisions idem 245487
# Le nombre de new collisions 32023
# Le nombre de collisions idem 245976
# Le nombre de new collisions 32043
# Le nombre de collisions idem 246456
# Le nombre de new collisions 32052
# Le nombre de collisions idem 246947
# Le nombre de new collisions 32062
# Le nombre de collisions idem 247437
# Le nombre de new collisions 32071
# Le nombre de collisions idem 247928
# Le nombre de new collisions 32078
# Le nombre de collisions idem 248421
# Le nombre de new collisions 32087
# Le nombre de collisions idem 248912
# Le nombre de new collisions 32093
# Le nombre de collisions idem 249406
# Le nombre de new collisions 32104
# Le nombre de collisions idem 249895
# Le nombre de new collisions 32113
# Le nombre de collisions idem 250386
# Le nombre de new collisions 32124
# Le nombre de collisions idem 250875
# Le nombre de new collisions 32128
# Le nombre de collisions idem 251371
# Le nombre de new collisions 32142
# Le nombre de collisions idem 251857
# Le nombre de new collisions 32151
# Le nombre de collisions idem 252348
# Le nombre de new collisions 32154
# Le nombre de collisions idem 252845
# Le nombre de new collisions 32158
# Le nombre de collisions idem 253341
# Le nombre de new collisions 32165
# Le nombre de collisions idem 253834
# Le nombre de new collisions 32173
# Le nombre de collisions idem 254326
# Le nombre de new collisions 32182
# Le nombre de collisions idem 254817
# Le nombre de new collisions 32191
# Le nombre de collisions idem 255308
# Le nombre de new collisions 32200
# Le nombre de collisions idem 255799
# Le nombre de new collisions 32205
# Le nombre de collisions idem 256294
# Le nombre de new collisions 32207
# Le nombre de collisions idem 256792
# Le nombre de new collisions 32213
# Le nombre de collisions idem 257286
# Le nombre de new collisions 32223
# Le nombre de collisions idem 257776
# Le nombre de new collisions 32228
# Le nombre de collisions idem 258271
# Le nombre de new collisions 32232
# Le nombre de collisions idem 258767
# Le nombre de new collisions 32245
# Le nombre de collisions idem 259254
# Le nombre de new collisions 32255
# Le nombre de collisions idem 259744
# Le nombre de new collisions 32260
# Le nombre de collisions idem 260239
# Le nombre de new collisions 32269
# Le nombre de collisions idem 260730
# Le nombre de new collisions 32276
# Le nombre de collisions idem 261223
# Le nombre de new collisions 32282
# Le nombre de collisions idem 261717
# Le nombre de new collisions 32289
# Le nombre de collisions idem 262210
# Le nombre de new collisions 32293
# Le nombre de collisions idem 262706
# Le nombre de new collisions 32298
# Le nombre de collisions idem 263201
# Le nombre de new collisions 32305
# Le nombre de collisions idem 263694
# Le nombre de new collisions 32305
# Le nombre de collisions idem 264194
#
# On varie NEW_STEP, on utilise la constante 8
# Le nombre de new collisions 32552
# Le nombre de collisions idem 264447
# Le nombre de new collisions 32806
# Le nombre de collisions idem 264693
# Le nombre de new collisions 33061
# Le nombre de collisions idem 264938
# Le nombre de new collisions 33320
# Le nombre de collisions idem 265179
# Le nombre de new collisions 33548
# Le nombre de collisions idem 265451
# Le nombre de new collisions 33783
# Le nombre de collisions idem 265716
# Le nombre de new collisions 34033
# Le nombre de collisions idem 265966
# Le nombre de new collisions 34265
# Le nombre de collisions idem 266234
# Le nombre de new collisions 34478
# Le nombre de collisions idem 266521
# Le nombre de new collisions 34712
# Le nombre de collisions idem 266787
# Le nombre de new collisions 34962
# Le nombre de collisions idem 267037
# Le nombre de new collisions 35193
# Le nombre de collisions idem 267306
# Le nombre de new collisions 35424
# Le nombre de collisions idem 267575
# Le nombre de new collisions 35659
# Le nombre de collisions idem 267840
# Le nombre de new collisions 35906
# Le nombre de collisions idem 268093
# Le nombre de new collisions 36127
# Le nombre de collisions idem 268372
# Le nombre de new collisions 36330
# Le nombre de collisions idem 268669
# Le nombre de new collisions 36552
# Le nombre de collisions idem 268947
# Le nombre de new collisions 36762
# Le nombre de collisions idem 269237
# Le nombre de new collisions 36963
# Le nombre de collisions idem 269536
# Le nombre de new collisions 37188
# Le nombre de collisions idem 269811
# Le nombre de new collisions 37397
# Le nombre de collisions idem 270102
# Le nombre de new collisions 37601
# Le nombre de collisions idem 270398
# Le nombre de new collisions 37815
# Le nombre de collisions idem 270684
# Le nombre de new collisions 38046
# Le nombre de collisions idem 270953
# Le nombre de new collisions 38260
# Le nombre de collisions idem 271239
# Le nombre de new collisions 38463
# Le nombre de collisions idem 271536
# Le nombre de new collisions 38664
# Le nombre de collisions idem 271835
# Le nombre de new collisions 38885
# Le nombre de collisions idem 272114
# Le nombre de new collisions 39083
# Le nombre de collisions idem 272416
# Le nombre de new collisions 39277
# Le nombre de collisions idem 272722
# Le nombre de new collisions 39474
# Le nombre de collisions idem 273025
# Le nombre de new collisions 39677
# Le nombre de collisions idem 273322
# Le nombre de new collisions 39892
# Le nombre de collisions idem 273607
# Le nombre de new collisions 40088
# Le nombre de collisions idem 273911
# Le nombre de new collisions 40269
# Le nombre de collisions idem 274230
# Le nombre de new collisions 40475
# Le nombre de collisions idem 274524
# Le nombre de new collisions 40672
# Le nombre de collisions idem 274827
# Le nombre de new collisions 40850
# Le nombre de collisions idem 275149
# Le nombre de new collisions 41019
# Le nombre de collisions idem 275480
# Le nombre de new collisions 41211
# Le nombre de collisions idem 275788
# Le nombre de new collisions 41392
# Le nombre de collisions idem 276107
# Le nombre de new collisions 41590
# Le nombre de collisions idem 276409
# Le nombre de new collisions 41779
# Le nombre de collisions idem 276720
# Le nombre de new collisions 41977
# Le nombre de collisions idem 277022
# Le nombre de new collisions 42164
# Le nombre de collisions idem 277335
# Le nombre de new collisions 42349
# Le nombre de collisions idem 277650
# Le nombre de new collisions 42537
# Le nombre de collisions idem 277962
# Le nombre de new collisions 42705
# Le nombre de collisions idem 278294
# Le nombre de new collisions 42873
# Le nombre de collisions idem 278626
# Le nombre de new collisions 43045
# Le nombre de collisions idem 278954
# Le nombre de new collisions 43207
# Le nombre de collisions idem 279292
# Le nombre de new collisions 43364
# Le nombre de collisions idem 279635
# Le nombre de new collisions 43533
# Le nombre de collisions idem 279966
# Le nombre de new collisions 43705
# Le nombre de collisions idem 280294
# Le nombre de new collisions 43876
# Le nombre de collisions idem 280623
# Le nombre de new collisions 44036
# Le nombre de collisions idem 280963
# Le nombre de new collisions 44191
# Le nombre de collisions idem 281308
# Le nombre de new collisions 44343
# Le nombre de collisions idem 281656
# Le nombre de new collisions 44497
# Le nombre de collisions idem 282002
# Le nombre de new collisions 44643
# Le nombre de collisions idem 282356
# Le nombre de new collisions 44814
# Le nombre de collisions idem 282685
# Le nombre de new collisions 44984
# Le nombre de collisions idem 283015
# Le nombre de new collisions 45139
# Le nombre de collisions idem 283360
# Le nombre de new collisions 45275
# Le nombre de collisions idem 283724
# Le nombre de new collisions 45419
# Le nombre de collisions idem 284080
# Le nombre de new collisions 45584
# Le nombre de collisions idem 284415
# Le nombre de new collisions 45730
# Le nombre de collisions idem 284769
# Le nombre de new collisions 45895
# Le nombre de collisions idem 285104
# Le nombre de new collisions 46039
# Le nombre de collisions idem 285460
# Le nombre de new collisions 46180
# Le nombre de collisions idem 285819
# Le nombre de new collisions 46335
# Le nombre de collisions idem 286164
# Le nombre de new collisions 46474
# Le nombre de collisions idem 286525
# Le nombre de new collisions 46609
# Le nombre de collisions idem 286890
# Le nombre de new collisions 46767
# Le nombre de collisions idem 287232
# Le nombre de new collisions 46899
# Le nombre de collisions idem 287600
# Le nombre de new collisions 47055
# Le nombre de collisions idem 287944
# Le nombre de new collisions 47192
# Le nombre de collisions idem 288307
# Le nombre de new collisions 47334
# Le nombre de collisions idem 288665
# Le nombre de new collisions 47484
# Le nombre de collisions idem 289015
# Le nombre de new collisions 47612
# Le nombre de collisions idem 289387
# Le nombre de new collisions 47759
# Le nombre de collisions idem 289740
# Le nombre de new collisions 47885
# Le nombre de collisions idem 290114
# Le nombre de new collisions 48022
# Le nombre de collisions idem 290477
# Le nombre de new collisions 48151
# Le nombre de collisions idem 290848
# Le nombre de new collisions 48276
# Le nombre de collisions idem 291223
# Le nombre de new collisions 48411
# Le nombre de collisions idem 291588
# Le nombre de new collisions 48540
# Le nombre de collisions idem 291959
# Le nombre de new collisions 48666
# Le nombre de collisions idem 292333
# Le nombre de new collisions 48787
# Le nombre de collisions idem 292712
# Le nombre de new collisions 48919
# Le nombre de collisions idem 293080
# Le nombre de new collisions 49044
# Le nombre de collisions idem 293455
# Le nombre de new collisions 49189
# Le nombre de collisions idem 293810
# Le nombre de new collisions 49328
# Le nombre de collisions idem 294171
# Le nombre de new collisions 49436
# Le nombre de collisions idem 294563
# Le nombre de new collisions 49549
# Le nombre de collisions idem 294950
# Le nombre de new collisions 49655
# Le nombre de collisions idem 295344
# Le nombre de new collisions 49768
# Le nombre de collisions idem 295731
# Le nombre de new collisions 49890
# Le nombre de collisions idem 296109
# Le nombre de new collisions 50015
# Le nombre de collisions idem 296484
# Le nombre de new collisions 50138
# Le nombre de collisions idem 296861
# Le nombre de new collisions 50258
# Le nombre de collisions idem 297241
# Le nombre de new collisions 50383
# Le nombre de collisions idem 297616
# Le nombre de new collisions 50495
# Le nombre de collisions idem 298004
# Le nombre de new collisions 50607
# Le nombre de collisions idem 298392
# Le nombre de new collisions 50728
# Le nombre de collisions idem 298771
# Le nombre de new collisions 50831
# Le nombre de collisions idem 299168
# Le nombre de new collisions 50948
# Le nombre de collisions idem 299551
# Le nombre de new collisions 51061
# Le nombre de collisions idem 299938
# Le nombre de new collisions 51167
# Le nombre de collisions idem 300332
# Le nombre de new collisions 51268
# Le nombre de collisions idem 300731
# Le nombre de new collisions 51376
# Le nombre de collisions idem 301123
# Le nombre de new collisions 51465
# Le nombre de collisions idem 301534
# Le nombre de new collisions 51573
# Le nombre de collisions idem 301926
# Le nombre de new collisions 51685
# Le nombre de collisions idem 302314
# Le nombre de new collisions 51791
# Le nombre de collisions idem 302708
# Le nombre de new collisions 51905
# Le nombre de collisions idem 303094
# Le nombre de new collisions 52000
# Le nombre de collisions idem 303499
# Le nombre de new collisions 52084
# Le nombre de collisions idem 303915
# Le nombre de new collisions 52194
# Le nombre de collisions idem 304305
# Le nombre de new collisions 52291
# Le nombre de collisions idem 304708
# Le nombre de new collisions 52387
# Le nombre de collisions idem 305112
# Le nombre de new collisions 52494
# Le nombre de collisions idem 305505
# Le nombre de new collisions 52580
# Le nombre de collisions idem 305919
# Le nombre de new collisions 52681
# Le nombre de collisions idem 306318
# Le nombre de new collisions 52780
# Le nombre de collisions idem 306719
# Le nombre de new collisions 52873
# Le nombre de collisions idem 307126
# Le nombre de new collisions 52971
# Le nombre de collisions idem 307528
# Le nombre de new collisions 53057
# Le nombre de collisions idem 307942
# Le nombre de new collisions 53167
# Le nombre de collisions idem 308332
# Exception ignored in: <function SmartPointer.__del__ at 0x00000280758E3288>
# Traceback (most recent call last):
#   File "C:\Users\Usuario\anaconda3\lib\site-packages\Crypto\Util\_raw_api.py", line 278, in __del__
#     self._destructor(self._raw_pointer)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-dd166baf6cce> in <module>
#       1 debut = time.time()
# ----> 2 res = golden_collision(F, M1, C1,M2,C2 ,kp, l )
#       3 fin = time.time()
#       4 print("Le temps utilisé :", fin-debut)
#
# <ipython-input-28-c4a0c16d7bcb> in golden_collision(F, M1, C1, M2, C2, kp, l)
#      38             continue
#      39
# ---> 40         stat.n_new_collisions += 1
#      41         liste.append(colli)
#      42
#
# KeyboardInterrupt:

# %%
# verification 
"""
t1 = ((key1,0), (key2,1))
t2 = ((key2,1), (key1,0))
if ((t1) in res[0]) | ((t2) in res[0]) : 
    print("trouvee")
else: 
    print("tres Tres gros PB ")
"""

# %%
debut = time.time()
res = golden_collision_parr(F, M1, C1,M2,C2 ,kp, l )
fin = time.time()
print("Le temps utilisé :", fin-debut)
